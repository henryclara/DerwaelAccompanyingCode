# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.interpolate
import netCDF4 as nc
import xarray as xr
import scipy.ndimage
import scipy as sp
import alphashape
from scipy import interpolate
from shapely.geometry import Point
from shapely.geometry.polygon import Polygon
from matplotlib import style
from pathlib import Path  
style.use('ggplot') or plt.style.use('ggplot')

# %%
# Read in the observed stratigraphy data

radardata = {}
for i in range(1,8):
    radardata['data' + str(i)] = pd.read_csv('../Data/AdjustedRadarStatigraphy/Observed/RadarSegment' + str(i) + '.csv', sep=",")
radardata
# Out:
# {'data1':       index        psX        psY   base  IRH0    Surface  StratElev1  \
#  0         0  961154.51  1956754.7  178.2     0   7.360430         NaN
#  1         1  961159.69  1956751.7  178.4     0   7.700226         NaN
#  2         2  961164.87  1956748.6  178.7     0   8.049260         NaN
#  3         3  961170.05  1956745.6  178.7     0   8.401228         NaN
#  4         4  961175.23  1956742.5  179.1     0   8.762635         NaN
#  ...     ...        ...        ...    ...   ...        ...         ...
#  5195   5195  987891.95  1940631.6  321.8     0  33.207766   28.802378
#  5196   5196  987896.27  1940627.4  321.8     0  33.209596   28.603297
#  5197   5197  987900.59  1940623.3  321.8     0  33.211438   28.605139
#  5198   5198  987904.90  1940619.1  321.8     0  33.213361   28.607061
#  5199   5199  987909.22  1940614.9  321.8     0  33.215331   28.609032
#
#        StratElev2  StratElev3  StratElev4  StratElev5  StratElev6  StratElev7  \
#  0            NaN         NaN         NaN         NaN         NaN         NaN
#  1            NaN         NaN         NaN         NaN         NaN         NaN
#  2            NaN         NaN         NaN         NaN         NaN         NaN
#  3            NaN         NaN         NaN         NaN         NaN         NaN
#  4            NaN         NaN         NaN         NaN         NaN         NaN
#  ...          ...         ...         ...         ...         ...         ...
#  5195   25.133509   19.374249   14.698777         NaN         NaN         NaN
#  5196   25.127526   19.522354   14.934095         NaN         NaN         NaN
#  5197   25.129369   19.524196   14.935937         NaN         NaN         NaN
#  5198   25.131291   19.526118   14.937860         NaN         NaN         NaN
#  5199   25.133262   19.528089   14.939830         NaN         NaN         NaN
#
#        StratElev8  StratElev9  StratElev10  StratElev11  StratElev12
#  0            NaN         NaN          NaN          NaN          NaN
#  1            NaN         NaN          NaN          NaN          NaN
#  2            NaN         NaN          NaN          NaN          NaN
#  3            NaN         NaN          NaN          NaN          NaN
#  4            NaN         NaN          NaN          NaN          NaN
#  ...          ...         ...          ...          ...          ...
#  5195         NaN         NaN          NaN          NaN          NaN
#  5196         NaN         NaN          NaN          NaN          NaN
#  5197         NaN         NaN          NaN          NaN          NaN
#  5198         NaN         NaN          NaN          NaN          NaN
#  5199         NaN         NaN          NaN          NaN          NaN
#
#  [5200 rows x 18 columns],
#  'data2':       index        psX        psY   base  IRH0     Surface  StratElev1  \
#  0      6200  986637.96  1936038.6  328.2     0   33.943100         NaN
#  1      6201  986631.98  1936037.7  328.2     0   33.940299         NaN
#  2      6202  986625.99  1936036.8  328.0     0   33.937488         NaN
#  3      6203  986620.01  1936035.9  328.0     0   33.934677         NaN
#  4      6204  986614.03  1936035.0  327.7     0   33.931860         NaN
#  ...     ...        ...        ...    ...   ...         ...         ...
#  5795  11995  956240.22  1952741.3  267.2     0  110.641011         NaN
#  5796  11996  956235.06  1952744.4  266.8     0  110.453883         NaN
#  5797  11997  956229.90  1952747.5  266.5     0  110.266848         NaN
#  5798  11998  956224.75  1952750.6  266.3     0  110.080000         NaN
#  5799  11999  956219.59  1952753.7  266.3     0  109.893149         NaN
#
#        StratElev2  StratElev3  StratElev4  StratElev5  StratElev6  StratElev7  \
#  0      25.446772   20.452469   14.621253         NaN         NaN         NaN
#  1      25.443971   20.449668   14.618452         NaN         NaN         NaN
#  2      25.441160   20.446858   15.017278         NaN         NaN         NaN
#  3      25.667131   20.461802   15.430936         NaN         NaN         NaN
#  4      25.664315   20.077079   15.421650         NaN         NaN         NaN
#  ...          ...         ...         ...         ...         ...         ...
#  5795         NaN  106.034712  102.210180         NaN   96.187700   80.908861
#  5796         NaN  106.048495  102.170054         NaN   96.159959   80.898296
#  5797         NaN  105.861459  101.983019         NaN   95.972923   80.893328
#  5798         NaN  105.873794  102.011827         NaN   96.252567   80.951962
#  5799         NaN  106.080043  101.831879         NaN   96.226707   80.761579
#
#        StratElev8  StratElev9  StratElev10  StratElev11  StratElev12
#  0            NaN         NaN          NaN          NaN          NaN
#  1            NaN         NaN          NaN          NaN          NaN
#  2            NaN         NaN          NaN          NaN          NaN
#  3            NaN         NaN          NaN          NaN          NaN
#  4            NaN         NaN          NaN          NaN          NaN
#  ...          ...         ...          ...          ...          ...
#  5795         NaN   68.950770    63.656396    54.053071    47.300581
#  5796         NaN   69.041532    63.660844    54.156660    47.313066
#  5797         NaN   68.860907    63.114226    53.979137    47.325659
#  5798         NaN   68.656057    63.092478    53.961774    47.405907
#  5799         NaN   68.465675    62.902095    53.771391    47.215524
#
#  [5800 rows x 18 columns],
#  'data3':       index        psX        psY   base  IRH0     Surface  StratElev1  \
#  0     12100  950161.21  1950431.4  210.3     0   66.744422         NaN
#  1     12101  950166.29  1950428.2  209.4     0   67.041133         NaN
#  2     12102  950171.37  1950425.0  209.2     0   67.337865         NaN
#  3     12103  950176.45  1950421.8  208.5     0   67.634617         NaN
#  4     12104  950181.53  1950418.6  208.7     0   67.931390         NaN
#  ...     ...        ...        ...    ...   ...         ...         ...
#  3395  15495  967494.21  1939671.0  467.9     0  329.552869  322.701130
#  3396  15496  967498.42  1939666.8  467.9     0  329.442054  322.590315
#  3397  15497  967502.63  1939662.5  467.7     0  329.326067  322.619922
#  3398  15498  967506.82  1939658.2  467.9     0  329.207798  322.356059
#  3399  15499  967511.00  1939653.8  467.9     0  329.088853  322.237114
#
#        StratElev2  StratElev3  StratElev4  StratElev5  StratElev6  StratElev7  \
#  0            NaN         NaN         NaN         NaN         NaN         NaN
#  1            NaN         NaN         NaN         NaN         NaN         NaN
#  2            NaN         NaN         NaN         NaN         NaN         NaN
#  3            NaN         NaN         NaN         NaN         NaN         NaN
#  4            NaN         NaN         NaN         NaN         NaN         NaN
#  ...          ...         ...         ...         ...         ...         ...
#  3395  317.904644  304.781067  295.906702  285.248487  267.586937  247.008698
#  3396  317.645084  304.680581  295.806215  284.870248  267.100761  246.908968
#  3397  317.686394  304.385774  295.857880  285.022028  267.166283  246.979203
#  3398  318.002223  304.667321  295.717255  284.881403  267.025657  246.442638
#  3399  317.440628  304.581973  295.631907  284.518118  266.942829  246.359810
#
#        StratElev8  StratElev9  StratElev10  StratElev11  StratElev12
#  0            NaN         NaN          NaN          NaN          NaN
#  1            NaN         NaN          NaN          NaN          NaN
#  2            NaN         NaN          NaN          NaN          NaN
#  3            NaN         NaN          NaN          NaN          NaN
#  4            NaN         NaN          NaN          NaN          NaN
#  ...          ...         ...          ...          ...          ...
#  3395  230.319905  210.955545   191.053047   170.258581   154.151026
#  3396  229.921865  210.154050   190.247760   170.156488   153.847234
#  3397  230.094072  210.228701   190.625167   170.031614   153.218082
#  3398  229.651917  210.585470   190.481847   169.585906   153.074414
#  3399  229.569089  210.502642   190.399018   169.503078   152.991586
#
#  [3400 rows x 18 columns],
#  'data4':       index        psX        psY   base  IRH0     Surface  StratElev1  \
#  0     17500  966954.96  1940320.7  475.6     0  345.342846  338.491107
#  1     17501  966950.77  1940316.4  475.9     0  345.376482  338.524743
#  2     17502  966946.58  1940312.1  475.4     0  345.410097  338.558358
#  3     17503  966942.39  1940307.7  475.4     0  345.442757  338.591018
#  4     17504  966938.19  1940303.4  475.4     0  345.476506  338.624767
#  ...     ...        ...        ...    ...   ...         ...         ...
#  5195  22695  945252.39  1917893.3  466.3     0   48.885994         NaN
#  5196  22696  945247.81  1917889.4  466.5     0   48.884422         NaN
#  5197  22697  945243.24  1917885.5  466.5     0   48.882839         NaN
#  5198  22698  945238.66  1917881.6  466.8     0   48.881241         NaN
#  5199  22699  945234.08  1917877.7  467.0     0   48.879630         NaN
#
#        StratElev2  StratElev3  StratElev4  StratElev5  StratElev6  StratElev7  \
#  0     331.949274  320.655044  311.513736  300.473804  282.787126  262.192260
#  1     331.982910  320.514112  311.363932  300.502064  282.815386  262.220521
#  2     332.016525  320.722296  311.580987  300.726506  282.852667  262.455857
#  3     332.049186  320.754956  311.613647  300.759166  282.690917  262.289431
#  4     332.082934  320.788704  311.647395  300.792914  282.724666  262.323179
#  ...          ...         ...         ...         ...         ...         ...
#  5195   40.005302   34.754887   25.388107         NaN         NaN         NaN
#  5196   40.003729   34.599979   25.390624         NaN         NaN         NaN
#  5197   40.002147   34.598397   25.389042         NaN         NaN         NaN
#  5198   40.000548   34.596798   25.387443         NaN         NaN         NaN
#  5199   39.998937   34.595187   25.385832         NaN         NaN         NaN
#
#        StratElev8  StratElev9  StratElev10  StratElev11  StratElev12
#  0     245.693667  226.625490   206.520771   185.624156   168.708866
#  1     245.721927  226.653750   206.549031   185.652416   168.737126
#  2     245.959710  226.893263   206.789640   185.692096   168.978532
#  3     245.790838  226.722661   207.321830   185.721965   169.008400
#  4     245.824586  226.756409   207.053937   185.755464   169.041900
#  ...          ...         ...          ...          ...          ...
#  5195         NaN         NaN          NaN          NaN          NaN
#  5196         NaN         NaN          NaN          NaN          NaN
#  5197         NaN         NaN          NaN          NaN          NaN
#  5198         NaN         NaN          NaN          NaN          NaN
#  5199         NaN         NaN          NaN          NaN          NaN
#
#  [5200 rows x 18 columns],
#  'data5':       index        psX        psY   base  IRH0    Surface  StratElev1  \
#  0     25000  942095.88  1926388.0  489.0     0  52.030374   47.424075
#  1     25001  942100.23  1926392.2  489.3     0  52.032494   47.426195
#  2     25002  942104.58  1926396.3  489.5     0  52.034605   47.428306
#  3     25003  942108.92  1926400.5  489.5     0  52.036744   47.430445
#  4     25004  942113.27  1926404.6  489.7     0  52.038877   47.432578
#  ...     ...        ...        ...    ...   ...        ...         ...
#  7495  32495  975006.20  1957153.7  194.6     0  75.556838         NaN
#  7496  32496  975010.59  1957157.8  193.2     0  75.161155         NaN
#  7497  32497  975014.98  1957161.8  193.7     0  74.770189         NaN
#  7498  32498  975019.36  1957165.9  194.2     0  74.374589         NaN
#  7499  32499  975023.75  1957170.0  191.0     0  73.978363         NaN
#
#        StratElev2  StratElev3  StratElev4  StratElev5  StratElev6  StratElev7  \
#  0      43.388264         NaN   25.990409         NaN         NaN         NaN
#  1      43.390384         NaN   25.992529         NaN         NaN         NaN
#  2      43.392495         NaN   25.719701         NaN         NaN         NaN
#  3      43.605913         NaN   25.967535         NaN         NaN         NaN
#  4      43.396767         NaN   25.998912         NaN         NaN         NaN
#  ...          ...         ...         ...         ...         ...         ...
#  7495   70.406480         NaN         NaN         NaN         NaN         NaN
#  7496   70.010798         NaN         NaN         NaN         NaN         NaN
#  7497   69.825253         NaN         NaN         NaN         NaN         NaN
#  7498   69.224232         NaN         NaN         NaN         NaN         NaN
#  7499   69.372063         NaN         NaN         NaN         NaN         NaN
#
#        StratElev8  StratElev9  StratElev10  StratElev11  StratElev12
#  0            NaN         NaN          NaN          NaN          NaN
#  1            NaN         NaN          NaN          NaN          NaN
#  2            NaN         NaN          NaN          NaN          NaN
#  3            NaN         NaN          NaN          NaN          NaN
#  4            NaN         NaN          NaN          NaN          NaN
#  ...          ...         ...          ...          ...          ...
#  7495   49.806441         NaN    34.362982          NaN          NaN
#  7496   49.410759         NaN    33.686905          NaN          NaN
#  7497   48.799123         NaN    33.249979          NaN          NaN
#  7498   49.090805         NaN    33.211090          NaN          NaN
#  7499   48.135730         NaN    32.411876          NaN          NaN
#
#  [7500 rows x 18 columns],
#  'data6':       index        psX        psY   base  IRH0    Surface  StratElev1  \
#  0     32700  955089.19  1953243.7  234.4     0  73.378842         NaN
#  1     32701  955092.03  1953238.4  234.9     0  73.681794         NaN
#  2     32702  955094.88  1953233.2  236.7     0  73.980024         NaN
#  3     32703  955097.73  1953227.9  237.2     0  74.283398         NaN
#  4     32704  955100.58  1953222.6  237.2     0  74.586917         NaN
#  ...     ...        ...        ...    ...   ...        ...         ...
#  7295  39995  980315.75  1917916.7  365.5     0  38.279835   33.673536
#  7296  39996  980321.56  1917915.1  365.5     0  38.282219   33.876831
#  7297  39997  980327.38  1917913.5  366.0     0  38.284608   33.879219
#  7298  39998  980333.21  1917911.9  366.0     0  38.286999   33.881611
#  7299  39999  980339.04  1917910.4  366.2     0  38.289315   33.883927
#
#        StratElev2  StratElev3  StratElev4  StratElev5  StratElev6  StratElev7  \
#  0      69.172636         NaN         NaN         NaN         NaN         NaN
#  1      70.190812         NaN         NaN         NaN         NaN         NaN
#  2      70.296370         NaN         NaN         NaN         NaN         NaN
#  3      70.470293         NaN         NaN         NaN         NaN         NaN
#  4      70.773812         NaN         NaN         NaN         NaN         NaN
#  ...          ...         ...         ...         ...         ...         ...
#  7295   31.680303   26.883817   22.731391   19.081213         NaN         NaN
#  7296   31.696732   27.122248   22.364206   19.094255         NaN         NaN
#  7297   31.699120   27.124636   22.366595   19.096644         NaN         NaN
#  7298   31.503623   27.133967   22.608554   19.110467         NaN         NaN
#  7299   31.505940   27.136283   22.610870   19.112783         NaN         NaN
#
#        StratElev8  StratElev9  StratElev10  StratElev11  StratElev12
#  0            NaN         NaN    32.062379          NaN          NaN
#  1            NaN         NaN    32.129009          NaN          NaN
#  2            NaN         NaN    32.289090          NaN          NaN
#  3            NaN         NaN    32.636167          NaN          NaN
#  4            NaN         NaN    32.939685          NaN          NaN
#  ...          ...         ...          ...          ...          ...
#  7295         NaN         NaN          NaN          NaN          NaN
#  7296         NaN         NaN          NaN          NaN          NaN
#  7297         NaN         NaN          NaN          NaN          NaN
#  7298         NaN         NaN          NaN          NaN          NaN
#  7299         NaN         NaN          NaN          NaN          NaN
#
#  [7300 rows x 18 columns],
#  'data7':       index        psX        psY   base  IRH0    Surface  StratElev1  \
#  0     41700  976737.60  1912985.6  380.3     0  38.747078   33.250681
#  1     41701  976732.38  1912988.6  380.1     0  38.744997   33.248600
#  2     41702  976727.16  1912991.6  380.1     0  38.742878   33.385443
#  3     41703  976721.95  1912994.6  379.6     0  38.740726   33.383291
#  4     41704  976716.75  1912997.6  379.4     0  38.738539   33.793603
#  ...     ...        ...        ...    ...   ...        ...         ...
#  9497  51197  934870.77  1950742.5  327.3     0  34.632630         NaN
#  9498  51198  934865.73  1950745.9  328.0     0  34.610552         NaN
#  9499  51199  934860.69  1950749.2  328.0     0  34.588516         NaN
#  9500  51200  934855.64  1950752.6  329.8     0  34.566206         NaN
#  9501  51201  934850.59  1950755.9  330.0     0  34.543941         NaN
#
#        StratElev2  StratElev3  StratElev4  StratElev5  StratElev6  StratElev7  \
#  0      30.950140   25.983316   17.966128         NaN         NaN         NaN
#  1      31.149014   25.972324   17.955136         NaN         NaN         NaN
#  2      31.358512   25.971956   17.954768         NaN         NaN         NaN
#  3      31.356359   25.969804   17.952616         NaN         NaN         NaN
#  4      31.520120   26.221346   18.554921         NaN         NaN         NaN
#  ...          ...         ...         ...         ...         ...         ...
#  9497   29.482272   26.314879   22.280204         NaN         NaN         NaN
#  9498   29.253117   26.485374   22.464473         NaN         NaN         NaN
#  9499   29.231081   26.463338   22.663575         NaN         NaN         NaN
#  9500   29.208771   26.441028   22.641265         NaN         NaN         NaN
#  9501   29.393583   26.637735   22.630713         NaN         NaN         NaN
#
#        StratElev8  StratElev9  StratElev10  StratElev11  StratElev12
#  0            NaN         NaN          NaN          NaN          NaN
#  1            NaN         NaN          NaN          NaN          NaN
#  2            NaN         NaN          NaN          NaN          NaN
#  3            NaN         NaN          NaN          NaN          NaN
#  4            NaN         NaN          NaN          NaN          NaN
#  ...          ...         ...          ...          ...          ...
#  9497         NaN         NaN          NaN          NaN          NaN
#  9498         NaN         NaN          NaN          NaN          NaN
#  9499         NaN         NaN          NaN          NaN          NaN
#  9500         NaN         NaN          NaN          NaN          NaN
#  9501         NaN         NaN          NaN          NaN          NaN
#
#  [9502 rows x 18 columns]}

# %%
# Read in the full radar lines

dataXY = pd.read_csv('../Data/AdjustedRadarStatigraphy/DepthAdjustedStratigraphyElevation.csv', sep=",")

# Record the corss-section index ranges

CSs = {'CS1' : [0, 5200], 'CS2' : [6200, 12000], 'CS3' : [12100, 15500], 'CS4' : [17500, 22700], \
       'CS5' : [25000, 32500], 'CS6' : [32700, 40000], 'CS7' : [41700, 51500]}

# %%
dataXY
# Out:
#              psX        psY   base  IRH0    Surface  StratElev1  StratElev2  \
# 0      961154.51  1956754.7  178.2     0   7.360430         NaN         NaN
# 1      961159.69  1956751.7  178.4     0   7.700226         NaN         NaN
# 2      961164.87  1956748.6  178.7     0   8.049260         NaN         NaN
# 3      961170.05  1956745.6  178.7     0   8.401228         NaN         NaN
# 4      961175.23  1956742.5  179.1     0   8.762635         NaN         NaN
# ...          ...        ...    ...   ...        ...         ...         ...
# 51197  934870.77  1950742.5  327.3     0  34.632630         NaN   29.482272
# 51198  934865.73  1950745.9  328.0     0  34.610552         NaN   29.253117
# 51199  934860.69  1950749.2  328.0     0  34.588516         NaN   29.231081
# 51200  934855.64  1950752.6  329.8     0  34.566206         NaN   29.208771
# 51201  934850.59  1950755.9  330.0     0  34.543941         NaN   29.393583
#
#        StratElev3  StratElev4  StratElev5  StratElev6  StratElev7  StratElev8  \
# 0             NaN         NaN         NaN         NaN         NaN         NaN
# 1             NaN         NaN         NaN         NaN         NaN         NaN
# 2             NaN         NaN         NaN         NaN         NaN         NaN
# 3             NaN         NaN         NaN         NaN         NaN         NaN
# 4             NaN         NaN         NaN         NaN         NaN         NaN
# ...           ...         ...         ...         ...         ...         ...
# 51197   26.314879   22.280204         NaN         NaN         NaN         NaN
# 51198   26.485374   22.464473         NaN         NaN         NaN         NaN
# 51199   26.463338   22.663575         NaN         NaN         NaN         NaN
# 51200   26.441028   22.641265         NaN         NaN         NaN         NaN
# 51201   26.637735   22.630713         NaN         NaN         NaN         NaN
#
#        StratElev9  StratElev10  StratElev11  StratElev12
# 0             NaN          NaN          NaN          NaN
# 1             NaN          NaN          NaN          NaN
# 2             NaN          NaN          NaN          NaN
# 3             NaN          NaN          NaN          NaN
# 4             NaN          NaN          NaN          NaN
# ...           ...          ...          ...          ...
# 51197         NaN          NaN          NaN          NaN
# 51198         NaN          NaN          NaN          NaN
# 51199         NaN          NaN          NaN          NaN
# 51200         NaN          NaN          NaN          NaN
# 51201         NaN          NaN          NaN          NaN
#
# [51202 rows x 17 columns]

# %%
# Read in GL data

dfGL = pd.read_csv("/Users/clara.henry/Documents/Derwael/Data/GroundingLine.csv")

points = np.column_stack((list(dfGL["Points:0"])[::10], list(dfGL["Points:1"])[::10]))

# [list(dfGL["Points:0"]), list(dfGL["Points:1"])]
alpha = 0.95 * alphashape.optimizealpha(points)
hull = alphashape.alphashape(points, alpha)
hull_pts = hull.exterior.coords.xy

hull_pts = hull_pts

for i in range(len(hull_pts[0])):
    hull_pts[0][i] = hull_pts[0][i]/1000
    hull_pts[1][i] = hull_pts[1][i]/1000
# Out:
# /Users/clara.henry/opt/anaconda3/lib/python3.9/site-packages/shapely/ops.py:42: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   source = iter(source)
# /Users/clara.henry/opt/anaconda3/lib/python3.9/site-packages/alphashape/optimizealpha.py:41: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   return all([polygon.intersects(point) for point in points])

# %%
# Define the ages

ages = [0.00001, 100, 200, 300, 400, 550, 750, 1000, 1300, 1800, 2500, 3700, 5500, 8000]
#ages = [0, 50, 100, 150, 200, 250, 300, 350, 400, 450, 500, 550, 600, 650, 700]

# %%
# Plot the first set of data

fig, ax = plt.subplots(1, 2, figsize=(18, 6), gridspec_kw={'width_ratios': [2, 1.3]})
for i in range(1,13):
    ax[0].plot(radardata['data1']['psX']/1000, radardata['data1']['StratElev' + str(i)], color='black', linewidth=1)
ax[0].plot(radardata['data1']['psX']/1000, radardata['data1']['StratElev' + str(i)], color='black', linewidth=1, label = 'Observed')
    
for i in ages:
    data = pd.read_csv('../Simulations/DerwaelSimulations/Contours/n3E0.6/ModelledSegment1.csv', sep=",")
    df = data.loc[data['age'] == i]
    df = df.sort_values(by='Points:0')
    ax[0].plot(df['Points:0']/1000, df['Points:2'], color='black', linestyle='dotted', linewidth=1)
ax[0].plot(df['Points:0']/1000, df['Points:2'], color='black', linestyle='dotted', linewidth=1, label = 'Modelled')
LSdata = pd.read_csv('../Simulations/DerwaelSimulations/Contours/n3E0.6/LS1.csv', sep=",")
LSdata = LSdata.sort_values(by='Points:0')
ax[0].plot(LSdata['Points:0']/1000, LSdata['Points:2'], linewidth=1, color='black')
# Plot the radar lines in the horizontal    

i = 1
    
ax[1].scatter(dataXY['psX']/1000, dataXY['psY']/1000, s=5, color='grey')
ax[1].scatter(dataXY['psX'][CSs['CS' + str(i)][0]:CSs['CS' + str(i)][1]]/1000, dataXY['psY'][CSs['CS' + str(i)][0]:CSs['CS' + str(i)][1]]/1000)
ax[1].plot(hull_pts[0], hull_pts[1], color='black')

ax[0].set_xlabel('$x$ [km]', fontsize = 30)
ax[0].set_ylabel('Elevation [m, a.s.l.]', fontsize = 30)
ax[0].tick_params(axis='both', which='major', labelsize=15)
ax[0].legend(fontsize = 20)
ax[1].set_xlabel('$x$ [km]', fontsize = 30)
ax[1].set_ylabel('$y$ [km]', fontsize = 30)
ax[1].tick_params(axis='both', which='major', labelsize=15)

fig.savefig('../Figures/StratigraphyComparison/StratigraphyComparison' + str(i) + '.jpg', format='jpg', dpi=700, bbox_inches = "tight")

# %%
# Plot the second set of data

fig, ax = plt.subplots(1, 2, figsize=(18, 6), gridspec_kw={'width_ratios': [2, 1.3]})
for i in range(1,13):
    ax[0].plot(radardata['data2']['psX']/1000, radardata['data2']['StratElev' + str(i)], color='black', linewidth=1)
ax[0].plot(radardata['data2']['psX']/1000, radardata['data2']['StratElev' + str(i)], color='black', linewidth=1, label = 'Observed')

for i in ages:
    data = pd.read_csv('../Simulations/DerwaelSimulations/Contours/n3E0.6/ModelledSegment2.csv', sep=",")
    df = data.loc[data['age'] == i]
    df = df.sort_values(by='Points:0')
    ax[0].plot(df['Points:0']/1000, df['Points:2'], color='black', linestyle='dotted', linewidth=1)
ax[0].plot(df['Points:0']/1000, df['Points:2'], color='black', linestyle='dotted', linewidth=1, label = 'Modelled')
LSdata = pd.read_csv('../Simulations/DerwaelSimulations/Contours/n3E0.6/LS2.csv', sep=",")
LSdata = LSdata.sort_values(by='Points:0')
ax[0].plot(LSdata['Points:0']/1000, LSdata['Points:2'], linewidth=1, color='black')
# Plot the radar lines in the horizontal

i = 2
    
ax[1].scatter(dataXY['psX']/1000, dataXY['psY']/1000, s=5, color='grey')
ax[1].scatter(dataXY['psX'][CSs['CS' + str(i)][0]:CSs['CS' + str(i)][1]]/1000, dataXY['psY'][CSs['CS' + str(i)][0]:CSs['CS' + str(i)][1]]/1000)
ax[1].plot(hull_pts[0], hull_pts[1], color='black')

ax[0].set_xlabel('$x$ [km]', fontsize = 30)
ax[0].set_ylabel('Elevation [m, a.s.l.]', fontsize = 30)
ax[0].tick_params(axis='both', which='major', labelsize=15)
ax[0].legend(fontsize = 20)
ax[1].set_xlabel('$x$ [km]', fontsize = 30)
ax[1].set_ylabel('$y$ [km]', fontsize = 30)
ax[1].tick_params(axis='both', which='major', labelsize=15)

fig.savefig('../Figures/StratigraphyComparison/StratigraphyComparison' + str(i) + '.jpg', format='jpg', dpi=700, bbox_inches = "tight")

# %%
# Plot the third set of data

fig, ax = plt.subplots(1, 2, figsize=(18, 6), gridspec_kw={'width_ratios': [2, 1.3]})
for i in range(1,13):
    ax[0].plot(radardata['data3']['psX']/1000, radardata['data3']['StratElev' + str(i)], color='black', linewidth=1)
ax[0].plot(radardata['data3']['psX']/1000, radardata['data3']['StratElev' + str(i)], color='black', linewidth=1, label = 'Observed')

for i in ages:
    data = pd.read_csv('../Simulations/DerwaelSimulations/Contours/n3E0.6/ModelledSegment3.csv', sep=",")
    df = data.loc[data['age'] == i]
    df = df.sort_values(by='Points:0')
    ax[0].plot(df['Points:0']/1000, df['Points:2'], color='black', linestyle='dotted', linewidth=1)
ax[0].plot(df['Points:0']/1000, df['Points:2'], color='black', linestyle='dotted', linewidth=1, label = 'Modelled')
LSdata = pd.read_csv('../Simulations/DerwaelSimulations/Contours/n3E0.6/LS3.csv', sep=",")
LSdata = LSdata.sort_values(by='Points:0')
ax[0].plot(LSdata['Points:0']/1000, LSdata['Points:2'], linewidth=1, color='black')

# Plot the radar lines in the horizontal

i = 3
    
ax[1].scatter(dataXY['psX']/1000, dataXY['psY']/1000, s=5, color='grey')
ax[1].scatter(dataXY['psX'][CSs['CS' + str(i)][0]:CSs['CS' + str(i)][1]]/1000, dataXY['psY'][CSs['CS' + str(i)][0]:CSs['CS' + str(i)][1]]/1000)
ax[1].plot(hull_pts[0], hull_pts[1], color='black')

ax[0].set_xlabel('$x$ [km]', fontsize = 30)
ax[0].set_ylabel('Elevation [m, a.s.l.]', fontsize = 30)
ax[0].tick_params(axis='both', which='major', labelsize=15)
ax[0].legend(fontsize = 20)
ax[1].set_xlabel('$x$ [km]', fontsize = 30)
ax[1].set_ylabel('$y$ [km]', fontsize = 30)
ax[1].tick_params(axis='both', which='major', labelsize=15)

fig.savefig('../Figures/StratigraphyComparison/StratigraphyComparison' + str(i) + '.jpg', format='jpg', dpi=700, bbox_inches = "tight")

# %%
# Plot the fourth set of data

fig, ax = plt.subplots(1, 2, figsize=(18, 6), gridspec_kw={'width_ratios': [2, 1.3]})
for i in range(1,13):
    ax[0].plot(radardata['data4']['psX']/1000, radardata['data4']['StratElev' + str(i)], color='black', linewidth=1)
ax[0].plot(radardata['data4']['psX']/1000, radardata['data4']['StratElev' + str(i)], color='black', linewidth=1, label = 'Observed')

for i in ages:
    data = pd.read_csv('../Simulations/DerwaelSimulations/Contours/n3E0.6/ModelledSegment4.csv', sep=",")
    df = data.loc[data['age'] == i]
    df = df.sort_values(by='Points:0')
    ax[0].plot(df['Points:0']/1000, df['Points:2'], color='black', linestyle='dotted', linewidth=1)
ax[0].plot(df['Points:0']/1000, df['Points:2'], color='black', linestyle='dotted', linewidth=1, label = 'Modelled')
LSdata = pd.read_csv('../Simulations/DerwaelSimulations/Contours/n3E0.6/LS4.csv', sep=",")
LSdata = LSdata.sort_values(by='Points:0')
ax[0].plot(LSdata['Points:0']/1000, LSdata['Points:2'], linewidth=1, color='black')

# Plot the radar lines in the horizontal

i = 4
    
ax[1].scatter(dataXY['psX']/1000, dataXY['psY']/1000, s=5, color='grey')
ax[1].scatter(dataXY['psX'][CSs['CS' + str(i)][0]:CSs['CS' + str(i)][1]]/1000, dataXY['psY'][CSs['CS' + str(i)][0]:CSs['CS' + str(i)][1]]/1000)
ax[1].plot(hull_pts[0], hull_pts[1], color='black')      

ax[0].set_xlabel('$x$ [km]', fontsize = 30)
ax[0].set_ylabel('Elevation [m, a.s.l.]', fontsize = 30)
ax[0].tick_params(axis='both', which='major', labelsize=15)
ax[0].legend(fontsize = 20)
ax[1].set_xlabel('$x$ [km]', fontsize = 30)
ax[1].set_ylabel('$y$ [km]', fontsize = 30)
ax[1].tick_params(axis='both', which='major', labelsize=15)

fig.savefig('../Figures/StratigraphyComparison/StratigraphyComparison' + str(i) + '.jpg', format='jpg', dpi=700, bbox_inches = "tight")

# %%
# Plot the fifth set of data

fig, ax = plt.subplots(1, 2, figsize=(18, 6), gridspec_kw={'width_ratios': [2, 1.3]})
for i in range(1,13):
    ax[0].plot(radardata['data5']['psX']/1000, radardata['data5']['StratElev' + str(i)], color='black', linewidth=1)
ax[0].plot(radardata['data5']['psX']/1000, radardata['data5']['StratElev' + str(i)], color='black', linewidth=1, label = 'Observed')

for i in ages:
    data = pd.read_csv('../Simulations/DerwaelSimulations/Contours/n3E0.6/ModelledSegment5.csv', sep=",")
    df = data.loc[data['age'] == i]
    df = df.sort_values(by='Points:0')
    ax[0].plot(df['Points:0']/1000, df['Points:2'], color='black', linestyle='dotted', linewidth=1)
ax[0].plot(df['Points:0']/1000, df['Points:2'], color='black', linestyle='dotted', linewidth=1, label = 'Modelled')
LSdata = pd.read_csv('../Simulations/DerwaelSimulations/Contours/n3E0.6/LS5.csv', sep=",")
LSdata = LSdata.sort_values(by='Points:0')
ax[0].plot(LSdata['Points:0']/1000, LSdata['Points:2'], linewidth=1, color='black')
# Plot the radar lines in the horizontal

i = 5
    
ax[1].scatter(dataXY['psX']/1000, dataXY['psY']/1000, s=5, color='grey')
ax[1].scatter(dataXY['psX'][CSs['CS' + str(i)][0]:CSs['CS' + str(i)][1]]/1000, dataXY['psY'][CSs['CS' + str(i)][0]:CSs['CS' + str(i)][1]]/1000)
ax[1].plot(hull_pts[0], hull_pts[1], color='black')    
    
ax[0].set_xlabel('$x$ [km]', fontsize = 30)
ax[0].set_ylabel('Elevation [m, a.s.l.]', fontsize = 30)
ax[0].tick_params(axis='both', which='major', labelsize=15)
ax[0].legend(fontsize = 20)
ax[1].set_xlabel('$x$ [km]', fontsize = 30)
ax[1].set_ylabel('$y$ [km]', fontsize = 30)
ax[1].tick_params(axis='both', which='major', labelsize=15)

fig.savefig('../Figures/StratigraphyComparison/StratigraphyComparison' + str(i) + '.jpg', format='jpg', dpi=700, bbox_inches = "tight")

# %%
# Plot the sixth set of data

fig, ax = plt.subplots(1, 2, figsize=(18, 6), gridspec_kw={'width_ratios': [2, 1.3]})
for i in range(1,13):
    ax[0].plot(radardata['data6']['psX']/1000, radardata['data6']['StratElev' + str(i)], color='black', linewidth=1)
ax[0].plot(radardata['data6']['psX']/1000, radardata['data6']['StratElev' + str(i)], color='black', linewidth=1, label = 'Observed')

    
for i in ages:
    data = pd.read_csv('../Simulations/DerwaelSimulations/Contours/n3E0.6/ModelledSegment6.csv', sep=",")
    df = data.loc[data['age'] == i]
    df = df.sort_values(by='Points:0')
    ax[0].plot(df['Points:0']/1000, df['Points:2'], color='black', linestyle='dotted', linewidth=1)
ax[0].plot(df['Points:0']/1000, df['Points:2'], color='black', linestyle='dotted', linewidth=1, label = 'Modelled')
LSdata = pd.read_csv('../Simulations/DerwaelSimulations/Contours/n3E0.6/LS6.csv', sep=",")
LSdata = LSdata.sort_values(by='Points:0')
ax[0].plot(LSdata['Points:0']/1000, LSdata['Points:2'], linewidth=1, color='black')
# Plot the radar lines in the horizontal

i = 6
    
ax[1].scatter(dataXY['psX']/1000, dataXY['psY']/1000, s=5, color='grey')
ax[1].scatter(dataXY['psX'][CSs['CS' + str(i)][0]:CSs['CS' + str(i)][1]]/1000, dataXY['psY'][CSs['CS' + str(i)][0]:CSs['CS' + str(i)][1]]/1000)
ax[1].plot(hull_pts[0], hull_pts[1], color='black')

ax[0].set_xlabel('$x$ [km]', fontsize = 30)
ax[0].set_ylabel('Elevation [m, a.s.l.]', fontsize = 30)
ax[0].tick_params(axis='both', which='major', labelsize=15)
ax[0].legend(fontsize = 20)
ax[1].set_xlabel('$x$ [km]', fontsize = 30)
ax[1].set_ylabel('$y$ [km]', fontsize = 30)
ax[1].tick_params(axis='both', which='major', labelsize=15)

fig.savefig('../Figures/StratigraphyComparison/StratigraphyComparison_n4E06' + str(i) + '.jpg', format='jpg', dpi=700, bbox_inches = "tight")

# %%
# Plot the seventh set of data

fig, ax = plt.subplots(1, 2, figsize=(18, 6), gridspec_kw={'width_ratios': [2, 1.3]})
for i in range(1,13):
    ax[0].plot(radardata['data7']['psX']/1000, radardata['data7']['StratElev' + str(i)], color='black', linewidth=1)
ax[0].plot(radardata['data7']['psX']/1000, radardata['data7']['StratElev' + str(i)], color='black', linewidth=1, label = 'Observed')
    
for i in ages:
    data = pd.read_csv('../Simulations/DerwaelSimulations/Contours/n3E0.6/ModelledSegment7.csv', sep=",")
    df = data.loc[data['age'] == i]
    df = df.sort_values(by='Points:0')
    ax[0].plot(df['Points:0']/1000, df['Points:2'], color='black', linestyle='dotted', linewidth=1)
ax[0].plot(df['Points:0']/1000, df['Points:2'], color='black', linestyle='dotted', linewidth=1, label = 'Modelled')
LSdata = pd.read_csv('../Simulations/DerwaelSimulations/Contours/n3E0.6/LS7.csv', sep=",")
LSdata = LSdata.sort_values(by='Points:0')
ax[0].plot(LSdata['Points:0']/1000, LSdata['Points:2'], linewidth=1, color='black')
# Plot the radar lines in the horizontal

i = 7
    
ax[1].scatter(dataXY['psX']/1000, dataXY['psY']/1000, s=5, color='grey')
ax[1].scatter(dataXY['psX'][CSs['CS' + str(i)][0]:CSs['CS' + str(i)][1]]/1000, dataXY['psY'][CSs['CS' + str(i)][0]:CSs['CS' + str(i)][1]]/1000)
ax[1].plot(hull_pts[0], hull_pts[1], color='black')   

ax[0].set_xlabel('$x$ [km]', fontsize = 30)
ax[0].set_ylabel('Elevation [m, a.s.l.]', fontsize = 30)
ax[0].tick_params(axis='both', which='major', labelsize=15)
ax[0].legend(fontsize = 20)
ax[1].set_xlabel('$x$ [km]', fontsize = 30)
ax[1].set_ylabel('$y$ [km]', fontsize = 30)
ax[1].tick_params(axis='both', which='major', labelsize=15)

fig.savefig('../Figures/StratigraphyComparison/StratigraphyComparison' + str(i) + '.jpg', format='jpg', dpi=700, bbox_inches = "tight")
