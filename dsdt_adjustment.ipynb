# %%
import pandas as pd
import xarray as xr

# %%
df = pd.read_csv('../Data/dsdt.csv')

df = df.drop('Points:2', axis=1)
cols = df.columns.tolist()
cols = [cols[1], cols[2], cols[0]]
df = df[cols] 
a = df.to_csv('dsdtData.csv')
xr = df.to_xarray()
nc = xr.to_netcdf('my_netcdf_new.nc')
xr
# Out:
# <xarray.Dataset>
# Dimensions:   (index: 1708)
# Coordinates:
#   * index     (index) int64 0 1 2 3 4 5 6 ... 1701 1702 1703 1704 1705 1706 1707
# Data variables:
#     Points:0  (index) float64 9.589e+05 9.599e+05 ... 9.454e+05 9.461e+05
#     Points:1  (index) float64 1.922e+06 1.922e+06 ... 1.93e+06 1.931e+06
#     dsdt      (index) float64 0.2851 0.2826 -0.1909 ... 0.6829 2.575 1.212

# %%
df
# Out:
#       Points:0   Points:1     dsdt
# 0     958940.0  1921700.0  0.28513
# 1     959930.0  1921700.0  0.28263
# 2     954250.0  1921700.0 -0.19094
# 3     954830.0  1920800.0 -0.17156
# 4     958840.0  1920700.0  0.29297
# ...        ...        ...      ...
# 1703  948060.0  1929200.0  0.82249
# 1704  944960.0  1931300.0  2.24360
# 1705  948600.0  1928900.0  0.68288
# 1706  945390.0  1930400.0  2.57530
# 1707  946110.0  1930700.0  1.21160
#
# [1708 rows x 3 columns]
